# %%
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from plotnine import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-defed27b7b46> in <module>()
#       4 get_ipython().magic('matplotlib inline')
#       5 import seaborn as sns
# ----> 6 from plotnine import *
#
# ModuleNotFoundError: No module named 'plotnine'

# %%
#read the file
df = pd.read_csv("Bechdel_detailed.csv")
#drop unuseful columns
df = df.drop(columns = ['Unnamed: 0', "id", "submitterid", "visible","date"])
#first insight into db
df.describe().T
# Out:
#           count          mean           std     min      25%       50%  \
# year     9373.0  1.995967e+03  2.507238e+01  1874.0   1988.0    2006.0
# rating   9373.0  2.123653e+00  1.105398e+00     0.0      1.0       3.0
# dubious  9074.0  8.926603e-02  2.851431e-01     0.0      0.0       0.0
# imdbid   9373.0  1.481312e+06  2.210870e+06     1.0  99731.0  423382.0
#
#                75%         max
# year        2013.0      2021.0
# rating         3.0         3.0
# dubious        0.0         1.0
# imdbid   1869716.0  15943414.0

# %%
#check if there are duplicates and delete the ones
df.duplicated().sum()
df.drop_duplicates(inplace = True)
#check for null values
df.isnull().sum()
#just dubious has missing values so we will keep it
# Out:
# title        0
# year         0
# rating       0
# dubious    299
# imdbid       0
# dtype: int64

# %%
#open IMDB db
imdb = pd.read_csv('movie_metadata.csv')
#drop unesuful columns
imdb = imdb.drop(columns = ['color', 'director_name', 'num_critic_for_reviews', 'duration',
       'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
       'actor_1_facebook_likes', 'actor_1_name',
        'num_voted_users', 'cast_total_facebook_likes',
       'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
        'num_user_for_reviews', 
        'actor_2_facebook_likes',
       'aspect_ratio', 'movie_facebook_likes'])
# #check if there are duplicates and delete the ones
imdb.duplicated().sum()
imdb.drop_duplicates(inplace = True)
imdb
# Out:
#             gross                           genres  \
# 0     760505847.0  Action|Adventure|Fantasy|Sci-Fi
# 1     309404152.0         Action|Adventure|Fantasy
# 2     200074175.0        Action|Adventure|Thriller
# 3     448130642.0                  Action|Thriller
# 4             NaN                      Documentary
# ...           ...                              ...
# 5038          NaN                     Comedy|Drama
# 5039          NaN     Crime|Drama|Mystery|Thriller
# 5040          NaN            Drama|Horror|Thriller
# 5041      10443.0             Comedy|Drama|Romance
# 5042      85222.0                      Documentary
#
#                                             movie_title  \
# 0                                               Avatar
# 1             Pirates of the Caribbean: At World's End
# 2                                              Spectre
# 3                                The Dark Knight Rises
# 4     Star Wars: Episode VII - The Force Awakens    ...
# ...                                                 ...
# 5038                           Signed Sealed Delivered
# 5039                         The Following
# 5040                              A Plague So Pleasant
# 5041                                  Shanghai Calling
# 5042                                 My Date with Drew
#
#                                         movie_imdb_link language country  \
# 0     http://www.imdb.com/title/tt0499549/?ref_=fn_t...  English     USA
# 1     http://www.imdb.com/title/tt0449088/?ref_=fn_t...  English     USA
# 2     http://www.imdb.com/title/tt2379713/?ref_=fn_t...  English      UK
# 3     http://www.imdb.com/title/tt1345836/?ref_=fn_t...  English     USA
# 4     http://www.imdb.com/title/tt5289954/?ref_=fn_t...      NaN     NaN
# ...                                                 ...      ...     ...
# 5038  http://www.imdb.com/title/tt3000844/?ref_=fn_t...  English  Canada
# 5039  http://www.imdb.com/title/tt2071645/?ref_=fn_t...  English     USA
# 5040  http://www.imdb.com/title/tt2107644/?ref_=fn_t...  English     USA
# 5041  http://www.imdb.com/title/tt2070597/?ref_=fn_t...  English     USA
# 5042  http://www.imdb.com/title/tt0378407/?ref_=fn_t...  English     USA
#
#      content_rating       budget  title_year  imdb_score
# 0             PG-13  237000000.0      2009.0         7.9
# 1             PG-13  300000000.0      2007.0         7.1
# 2             PG-13  245000000.0      2015.0         6.8
# 3             PG-13  250000000.0      2012.0         8.5
# 4               NaN          NaN         NaN         7.1
# ...             ...          ...         ...         ...
# 5038            NaN          NaN      2013.0         7.7
# 5039          TV-14          NaN         NaN         7.5
# 5040            NaN       1400.0      2013.0         6.3
# 5041          PG-13          NaN      2012.0         6.3
# 5042             PG       1100.0      2004.0         6.6
#
# [4921 rows x 10 columns]

# %%
#transform the imdb movie link to an id for merging purposes
imdb['imdbid']= imdb['movie_imdb_link'].apply(lambda x:float(str(x).split("/")[4][2:]))
#merge the two df
merged_df = pd.merge(df, imdb, how='inner', on=['imdbid'])
#transform year in datetime
merged_df['year'] = pd.to_datetime(merged_df['title_year'])
#select just year
merged_df['year'] = pd.DatetimeIndex(merged_df['year']).year 
# drop the unesuful column of both (title is well written in the imbdb one so keep that one)
merged_df = merged_df.drop(columns = ['title','title_year','movie_imdb_link','imdbid'])

# %%
#check for null values
merged_df.isnull().sum()
# Out:
# year                4
# rating              0
# dubious           224
# gross             210
# genres              0
# movie_title         0
# language            3
# country             0
# content_rating     32
# budget            151
# imdb_score          0
# dtype: int64

# %%
#check the null title_year
merged_df[merged_df['year'].isnull()]
#drop those rows
merged_df = merged_df[merged_df['year'].notna()]

# %%
#check for duplicates
merged_df.duplicated().sum()
# Out:
# 0

# %%
merged_df
#we can see there are some more duplicates with small differences, decide how to treat them
# Out:
#         year  rating  dubious        gross                          genres  \
# 0     1970.0     0.0      0.0          NaN               Drama|History|War
# 1     1970.0     2.0      0.0          NaN               Drama|Romance|War
# 2     1970.0     1.0      0.0      26435.0                    Drama|Sci-Fi
# 3     1970.0     3.0      1.0       9950.0             Crime|Drama|Romance
# 4     1970.0     3.0      0.0    2808000.0                 Musical|Romance
# ...      ...     ...      ...          ...                             ...
# 2842  1970.0     1.0      0.0  107225164.0  Action|Animation|Comedy|Family
# 2843  1970.0     2.0      0.0   35537564.0                          Comedy
# 2844  1970.0     1.0      0.0          NaN         Adventure|Drama|History
# 2845  1970.0     1.0      0.0          NaN         Adventure|Drama|History
# 2846  1970.0     1.0      0.0          NaN         Adventure|Drama|History
#
#                                             movie_title language  country  \
# 0     Intolerance: Love's Struggle Throughout the Ages       NaN      USA
# 1                                       The Big Parade       NaN      USA
# 2                                           Metropolis    German  Germany
# 3                                        Pandora's Box    German  Germany
# 4                                  The Broadway Melody   English      USA
# ...                                                 ...      ...      ...
# 2842                             The Angry Birds Movie   English      USA
# 2843                                     Dirty Grandpa   English      USA
# 2844                                           Ben-Hur   English      USA
# 2845                                           Ben-Hur   English      USA
# 2846                                           Ben-Hur   English      USA
#
#      content_rating       budget  imdb_score
# 0         Not Rated     385907.0         8.0
# 1         Not Rated     245000.0         8.3
# 2         Not Rated    6000000.0         8.3
# 3         Not Rated          NaN         8.0
# 4            Passed     379000.0         6.3
# ...             ...          ...         ...
# 2842             PG   73000000.0         6.3
# 2843              R   11500000.0         6.0
# 2844          PG-13          NaN         6.1
# 2845          PG-13  100000000.0         6.1
# 2846          PG-13  100000000.0         6.0
#
# [2843 rows x 11 columns]

# %%
merged_df['movie_title'].describe()
# Out:
# count         2843
# unique        2839
# top       Ben-Hur
# freq             3
# Name: movie_title, dtype: object

# %%
#a couple of movies appear twice
#remove movies with same year and title
merged_df = merged_df.drop(merged_df.loc[merged_df.duplicated(['movie_title','year'])].index)
#check if it worked
merged_df['movie_title'].describe()
# Out:
# count                                                  2839
# unique                                                 2839
# top       Intolerance: Love's Struggle Throughout the Ages
# freq                                                      1
# Name: movie_title, dtype: object

# %%
#divide genre into list for easier use
merged_df['genres']= merged_df['genres'].apply(lambda x:(str(x).split("|")))
merged_df
# Out:
#         year  rating  dubious        gross  \
# 0     1970.0     0.0      0.0          NaN
# 1     1970.0     2.0      0.0          NaN
# 2     1970.0     1.0      0.0      26435.0
# 3     1970.0     3.0      1.0       9950.0
# 4     1970.0     3.0      0.0    2808000.0
# ...      ...     ...      ...          ...
# 2840  1970.0     1.0      0.0          NaN
# 2841  1970.0     2.0      0.0    9658370.0
# 2842  1970.0     1.0      0.0  107225164.0
# 2843  1970.0     2.0      0.0   35537564.0
# 2844  1970.0     1.0      0.0          NaN
#
#                                    genres  \
# 0                   [Drama, History, War]
# 1                   [Drama, Romance, War]
# 2                         [Drama, Sci-Fi]
# 3                 [Crime, Drama, Romance]
# 4                      [Musical, Romance]
# ...                                   ...
# 2840                   [Biography, Drama]
# 2841                    [Comedy, Romance]
# 2842  [Action, Animation, Comedy, Family]
# 2843                             [Comedy]
# 2844          [Adventure, Drama, History]
#
#                                             movie_title language  country  \
# 0     Intolerance: Love's Struggle Throughout the Ages       NaN      USA
# 1                                       The Big Parade       NaN      USA
# 2                                           Metropolis    German  Germany
# 3                                        Pandora's Box    German  Germany
# 4                                  The Broadway Melody   English      USA
# ...                                                 ...      ...      ...
# 2840                             The Birth of a Nation   English      USA
# 2841                                 The Perfect Match   English      USA
# 2842                             The Angry Birds Movie   English      USA
# 2843                                     Dirty Grandpa   English      USA
# 2844                                           Ben-Hur   English      USA
#
#      content_rating      budget  imdb_score
# 0         Not Rated    385907.0         8.0
# 1         Not Rated    245000.0         8.3
# 2         Not Rated   6000000.0         8.3
# 3         Not Rated         NaN         8.0
# 4            Passed    379000.0         6.3
# ...             ...         ...         ...
# 2840              R  10000000.0         5.4
# 2841              R   5000000.0         4.5
# 2842             PG  73000000.0         6.3
# 2843              R  11500000.0         6.0
# 2844          PG-13         NaN         6.1
#
# [2839 rows x 11 columns]

# %% [markdown]
# ## visualizations

# %%
import plotly.express as px

# %%
#distribution of the ratings
merged_df['rating'].value_counts().plot.pie()
# Out:
# <AxesSubplot:ylabel='rating'>

# %%
#average imbd rating score per rating
rating_score_average = merged_df['imdb_score'].groupby(merged_df['rating']).mean()
rating_score_average.plot.bar()
# Out:
# <AxesSubplot:xlabel='rating'>
